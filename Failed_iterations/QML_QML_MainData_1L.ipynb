# %% [markdown]
# <a href="https://colab.research.google.com/github/JhaAyushCanCode/Quantum-Classical_Hybrid_ML/blob/main/QML_QML_Load_MainData_1L.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow tensorflow-datasets pennylane cirq tensorflow-quantum transformers seaborn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.9)
# Requirement already satisfied: pennylane in /usr/local/lib/python3.11/dist-packages (0.41.1)
# Requirement already satisfied: cirq in /usr/local/lib/python3.11/dist-packages (1.3.0)
# Requirement already satisfied: tensorflow-quantum in /usr/local/lib/python3.11/dist-packages (0.7.3)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.53.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.15.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from pennylane) (3.5)
# Requirement already satisfied: rustworkx>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.16.0)
# Requirement already satisfied: autograd in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.8.0)
# Requirement already satisfied: tomlkit in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.13.3)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.11/dist-packages (from pennylane) (1.4.4)
# Requirement already satisfied: autoray>=0.6.11 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.7.1)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.11/dist-packages (from pennylane) (5.5.2)
# Requirement already satisfied: pennylane-lightning>=0.41 in /usr/local/lib/python3.11/dist-packages (from pennylane) (0.41.1)
# Requirement already satisfied: diastatic-malt in /usr/local/lib/python3.11/dist-packages (from pennylane) (2.15.2)
# Requirement already satisfied: cirq-aqt==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-core==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-ft==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-google==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-ionq==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-pasqal==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-rigetti==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: cirq-web==1.3.0 in /usr/local/lib/python3.11/dist-packages (from cirq) (1.3.0)
# Requirement already satisfied: duet~=0.2.8 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->cirq) (0.2.9)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->cirq) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->cirq) (2.2.2)
# Requirement already satisfied: sortedcontainers~=2.0 in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->cirq) (2.4.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from cirq-core==1.3.0->cirq) (1.12)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from cirq-ft==1.3.0->cirq) (21.4.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from cirq-ft==1.3.0->cirq) (7.7.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.11/dist-packages (from cirq-ft==1.3.0->cirq) (7.16.6)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from cirq-ft==1.3.0->cirq) (5.10.4)
# Requirement already satisfied: google-api-core>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (2.25.1)
# Requirement already satisfied: proto-plus>=1.20.0 in /usr/local/lib/python3.11/dist-packages (from cirq-google==1.3.0->cirq) (1.26.1)
# Requirement already satisfied: pyquil<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from cirq-rigetti==1.3.0->cirq) (3.5.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy->cirq-core==1.3.0->cirq) (1.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.23.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib~=3.0->cirq-core==1.3.0->cirq) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->cirq) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->cirq-core==1.3.0->cirq) (2025.2)
# Requirement already satisfied: scipy-openblas32>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from pennylane-lightning>=0.41->pennylane) (0.3.30.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.70.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (2.38.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (1.71.2)
# Requirement already satisfied: deprecated<2.0.0,>=1.2.13 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.2.18)
# Requirement already satisfied: lark<0.12.0,>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.11.3)
# Requirement already satisfied: qcs-api-client<0.22.0,>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.21.6)
# Requirement already satisfied: rpcq<4.0.0,>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (3.11.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (8.5.0)
# Requirement already satisfied: types-deprecated<2.0.0.0,>=1.2.9.2 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.2.15.20250304)
# Requirement already satisfied: types-python-dateutil<3.0.0,>=2.8.19 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2.9.0.20250516)
# Requirement already satisfied: types-retry<0.10.0,>=0.9.9 in /usr/local/lib/python3.11/dist-packages (from pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.9.9.20250322)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->cirq-ft==1.3.0->cirq) (3.0.15)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->cirq-ft==1.3.0->cirq) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (3.1.6)
# Requirement already satisfied: jupyter-core>=4.7 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (5.8.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert->cirq-ft==1.3.0->cirq) (2.19.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->cirq-ft==1.3.0->cirq) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.11/dist-packages (from nbformat->cirq-ft==1.3.0->cirq) (4.17.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->cirq-ft==1.3.0->cirq) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert->cirq-ft==1.3.0->cirq) (1.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (4.9.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets->cirq-ft==1.3.0->cirq) (6.4.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (4.9.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.6->nbformat->cirq-ft==1.3.0->cirq) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core>=4.7->nbconvert->cirq-ft==1.3.0->cirq) (4.3.8)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (2.10.1)
# Requirement already satisfied: httpx<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.23.3)
# Requirement already satisfied: iso8601<2.0.0,>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.1.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.10.22)
# Requirement already satisfied: retrying<2.0.0,>=1.3.3 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.4.0)
# Requirement already satisfied: rfc3339<7.0,>=6.2 in /usr/local/lib/python3.11/dist-packages (from qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (6.2)
# Requirement already satisfied: msgpack<2.0,>=0.6 in /usr/local/lib/python3.11/dist-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.1.1)
# Requirement already satisfied: python-rapidjson in /usr/local/lib/python3.11/dist-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.20)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.11/dist-packages (from rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.18.14)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert->cirq-ft==1.3.0->cirq) (2.7)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.16.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in /usr/local/lib/python3.11/dist-packages (from rfc3986[idna2008]<2,>=1.3->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.5.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.8.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core>=1.14.0->google-api-core[grpc]>=1.14.0->cirq-google==1.3.0->cirq) (0.6.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.11/dist-packages (from ruamel.yaml->rpcq<4.0.0,>=3.10.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.2.12)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx<0.24.0,>=0.23.0->qcs-api-client<0.22.0,>=0.21.0->pyquil<4.0.0,>=3.2.0->cirq-rigetti==1.3.0->cirq) (4.9.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (0.2.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (21.2.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (2.22)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->cirq-ft==1.3.0->cirq) (1.8.0)

# %%
import pennylane as qml
from pennylane import numpy as np
import numpy as onp
import tensorflow as tf
import tensorflow_datasets as tfds
from transformers import BertTokenizer, TFBertModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.11/dist-packages/pennylane/capture/capture_operators.py:33: RuntimeWarning: PennyLane is not yet compatible with JAX versions > 0.4.28. You have version 0.5.2 installed. Please downgrade JAX to <=0.4.28 to avoid runtime errors.
#   warnings.warn(

# %%
# Load GoEmotions Dataset
dataset, info = tfds.load('goemotions', with_info=True)
train_dataset = dataset['train']

texts, labels = [], []

# Get list of emotion keys
emotion_keys = [key for key in list(info.features.keys()) if key not in ['comment_text']]

for example in tfds.as_numpy(train_dataset):
    texts.append(example['comment_text'].decode('utf-8'))

    # Get the index of the first label that is True
    label_index = next(i for i, key in enumerate(emotion_keys) if example[key])
    labels.append(label_index)

print(f"Total samples: {len(texts)}")
print(f"Number of classes: {len(emotion_keys)}")
# Out:
# Total samples: 43410
# Number of classes: 28

# %%
# Text embedding using BERT but in smaller batches due to overloading earlier

from transformers import BertTokenizer, TFBertModel
import numpy as np

# Load tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
bert_model = TFBertModel.from_pretrained('bert-base-uncased')

batch_size = 64  # Start safe
embeddings = []

for i in range(0, len(texts), batch_size):
    batch_texts = texts[i:i+batch_size]
    inputs = tokenizer(batch_texts, return_tensors='tf', padding=True, truncation=True, max_length=64)

    # Forward pass through BERT
    batch_embeddings = bert_model(inputs)[0][:, 0, :].numpy()  # CLS token embedding

    embeddings.append(batch_embeddings)

    print(f"Processed batch {i//batch_size + 1} / {len(texts)//batch_size + 1}")

# Combine all batches
embeddings = np.vstack(embeddings)
print(f"Final embedding shape: {embeddings.shape}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# Processed batch 1 / 679
# Processed batch 2 / 679
# Processed batch 3 / 679
# Processed batch 4 / 679
# Processed batch 5 / 679
# Processed batch 6 / 679
# Processed batch 7 / 679
# Processed batch 8 / 679
# Processed batch 9 / 679
# Processed batch 10 / 679
# Processed batch 11 / 679
# Processed batch 12 / 679
# Processed batch 13 / 679
# Processed batch 14 / 679
# Processed batch 15 / 679
# Processed batch 16 / 679
# Processed batch 17 / 679
# Processed batch 18 / 679
# Processed batch 19 / 679
# Processed batch 20 / 679
# Processed batch 21 / 679
# Processed batch 22 / 679
# Processed batch 23 / 679
# Processed batch 24 / 679
# Processed batch 25 / 679
# Processed batch 26 / 679
# Processed batch 27 / 679
# Processed batch 28 / 679
# Processed batch 29 / 679
# Processed batch 30 / 679
# Processed batch 31 / 679
# Processed batch 32 / 679
# Processed batch 33 / 679
# Processed batch 34 / 679
# Processed batch 35 / 679
# Processed batch 36 / 679
# Processed batch 37 / 679
# Processed batch 38 / 679
# Processed batch 39 / 679
# Processed batch 40 / 679
# Processed batch 41 / 679
# Processed batch 42 / 679
# Processed batch 43 / 679
# Processed batch 44 / 679
# Processed batch 45 / 679
# Processed batch 46 / 679
# Processed batch 47 / 679
# Processed batch 48 / 679
# Processed batch 49 / 679
# Processed batch 50 / 679
# Processed batch 51 / 679
# Processed batch 52 / 679
# Processed batch 53 / 679
# Processed batch 54 / 679
# Processed batch 55 / 679
# Processed batch 56 / 679
# Processed batch 57 / 679
# Processed batch 58 / 679
# Processed batch 59 / 679
# Processed batch 60 / 679
# Processed batch 61 / 679
# Processed batch 62 / 679
# Processed batch 63 / 679
# Processed batch 64 / 679
# Processed batch 65 / 679
# Processed batch 66 / 679
# Processed batch 67 / 679
# Processed batch 68 / 679
# Processed batch 69 / 679
# Processed batch 70 / 679
# Processed batch 71 / 679
# Processed batch 72 / 679
# Processed batch 73 / 679
# Processed batch 74 / 679
# Processed batch 75 / 679
# Processed batch 76 / 679
# Processed batch 77 / 679
# Processed batch 78 / 679
# Processed batch 79 / 679
# Processed batch 80 / 679
# Processed batch 81 / 679
# Processed batch 82 / 679
# Processed batch 83 / 679
# Processed batch 84 / 679
# Processed batch 85 / 679
# Processed batch 86 / 679
# Processed batch 87 / 679
# Processed batch 88 / 679
# Processed batch 89 / 679
# Processed batch 90 / 679
# Processed batch 91 / 679
# Processed batch 92 / 679
# Processed batch 93 / 679
# Processed batch 94 / 679
# Processed batch 95 / 679
# Processed batch 96 / 679
# Processed batch 97 / 679
# Processed batch 98 / 679
# Processed batch 99 / 679
# Processed batch 100 / 679
# Processed batch 101 / 679
# Processed batch 102 / 679
# Processed batch 103 / 679
# Processed batch 104 / 679
# Processed batch 105 / 679
# Processed batch 106 / 679
# Processed batch 107 / 679
# Processed batch 108 / 679
# Processed batch 109 / 679
# Processed batch 110 / 679
# Processed batch 111 / 679
# Processed batch 112 / 679
# Processed batch 113 / 679
# Processed batch 114 / 679
# Processed batch 115 / 679
# Processed batch 116 / 679
# Processed batch 117 / 679
# Processed batch 118 / 679
# Processed batch 119 / 679
# Processed batch 120 / 679
# Processed batch 121 / 679
# Processed batch 122 / 679
# Processed batch 123 / 679
# Processed batch 124 / 679
# Processed batch 125 / 679
# Processed batch 126 / 679
# Processed batch 127 / 679
# Processed batch 128 / 679
# Processed batch 129 / 679
# Processed batch 130 / 679
# Processed batch 131 / 679
# Processed batch 132 / 679
# Processed batch 133 / 679
# Processed batch 134 / 679
# Processed batch 135 / 679
# Processed batch 136 / 679
# Processed batch 137 / 679
# Processed batch 138 / 679
# Processed batch 139 / 679
# Processed batch 140 / 679
# Processed batch 141 / 679
# Processed batch 142 / 679
# Processed batch 143 / 679
# Processed batch 144 / 679
# Processed batch 145 / 679
# Processed batch 146 / 679
# Processed batch 147 / 679
# Processed batch 148 / 679
# Processed batch 149 / 679
# Processed batch 150 / 679
# Processed batch 151 / 679
# Processed batch 152 / 679
# Processed batch 153 / 679
# Processed batch 154 / 679
# Processed batch 155 / 679
# Processed batch 156 / 679
# Processed batch 157 / 679
# Processed batch 158 / 679
# Processed batch 159 / 679
# Processed batch 160 / 679
# Processed batch 161 / 679
# Processed batch 162 / 679
# Processed batch 163 / 679
# Processed batch 164 / 679
# Processed batch 165 / 679
# Processed batch 166 / 679
# Processed batch 167 / 679
# Processed batch 168 / 679
# Processed batch 169 / 679
# Processed batch 170 / 679
# Processed batch 171 / 679
# Processed batch 172 / 679
# Processed batch 173 / 679
# Processed batch 174 / 679
# Processed batch 175 / 679
# Processed batch 176 / 679
# Processed batch 177 / 679
# Processed batch 178 / 679
# Processed batch 179 / 679
# Processed batch 180 / 679
# Processed batch 181 / 679
# Processed batch 182 / 679
# Processed batch 183 / 679
# Processed batch 184 / 679
# Processed batch 185 / 679
# Processed batch 186 / 679
# Processed batch 187 / 679
# Processed batch 188 / 679
# Processed batch 189 / 679
# Processed batch 190 / 679
# Processed batch 191 / 679
# Processed batch 192 / 679
# Processed batch 193 / 679
# Processed batch 194 / 679
# Processed batch 195 / 679
# Processed batch 196 / 679
# Processed batch 197 / 679
# Processed batch 198 / 679
# Processed batch 199 / 679
# Processed batch 200 / 679
# Processed batch 201 / 679
# Processed batch 202 / 679
# Processed batch 203 / 679
# Processed batch 204 / 679
# Processed batch 205 / 679
# Processed batch 206 / 679
# Processed batch 207 / 679
# Processed batch 208 / 679
# Processed batch 209 / 679
# Processed batch 210 / 679
# Processed batch 211 / 679
# Processed batch 212 / 679
# Processed batch 213 / 679
# Processed batch 214 / 679
# Processed batch 215 / 679
# Processed batch 216 / 679
# Processed batch 217 / 679
# Processed batch 218 / 679
# Processed batch 219 / 679
# Processed batch 220 / 679
# Processed batch 221 / 679
# Processed batch 222 / 679
# Processed batch 223 / 679
# Processed batch 224 / 679
# Processed batch 225 / 679
# Processed batch 226 / 679
# Processed batch 227 / 679
# Processed batch 228 / 679
# Processed batch 229 / 679
# Processed batch 230 / 679
# Processed batch 231 / 679
# Processed batch 232 / 679
# Processed batch 233 / 679
# Processed batch 234 / 679
# Processed batch 235 / 679
# Processed batch 236 / 679
# Processed batch 237 / 679
# Processed batch 238 / 679
# Processed batch 239 / 679
# Processed batch 240 / 679
# Processed batch 241 / 679
# Processed batch 242 / 679
# Processed batch 243 / 679
# Processed batch 244 / 679
# Processed batch 245 / 679
# Processed batch 246 / 679
# Processed batch 247 / 679
# Processed batch 248 / 679
# Processed batch 249 / 679
# Processed batch 250 / 679
# Processed batch 251 / 679
# Processed batch 252 / 679
# Processed batch 253 / 679
# Processed batch 254 / 679
# Processed batch 255 / 679
# Processed batch 256 / 679
# Processed batch 257 / 679
# Processed batch 258 / 679
# Processed batch 259 / 679
# Processed batch 260 / 679
# Processed batch 261 / 679
# Processed batch 262 / 679
# Processed batch 263 / 679
# Processed batch 264 / 679
# Processed batch 265 / 679
# Processed batch 266 / 679
# Processed batch 267 / 679
# Processed batch 268 / 679
# Processed batch 269 / 679
# Processed batch 270 / 679
# Processed batch 271 / 679
# Processed batch 272 / 679
# Processed batch 273 / 679
# Processed batch 274 / 679
# Processed batch 275 / 679
# Processed batch 276 / 679
# Processed batch 277 / 679
# Processed batch 278 / 679
# Processed batch 279 / 679
# Processed batch 280 / 679
# Processed batch 281 / 679
# Processed batch 282 / 679
# Processed batch 283 / 679
# Processed batch 284 / 679
# Processed batch 285 / 679
# Processed batch 286 / 679
# Processed batch 287 / 679
# Processed batch 288 / 679
# Processed batch 289 / 679
# Processed batch 290 / 679
# Processed batch 291 / 679
# Processed batch 292 / 679
# Processed batch 293 / 679
# Processed batch 294 / 679
# Processed batch 295 / 679
# Processed batch 296 / 679
# Processed batch 297 / 679
# Processed batch 298 / 679
# Processed batch 299 / 679
# Processed batch 300 / 679
# Processed batch 301 / 679
# Processed batch 302 / 679
# Processed batch 303 / 679
# Processed batch 304 / 679
# Processed batch 305 / 679
# Processed batch 306 / 679
# Processed batch 307 / 679
# Processed batch 308 / 679
# Processed batch 309 / 679
# Processed batch 310 / 679
# Processed batch 311 / 679
# Processed batch 312 / 679
# Processed batch 313 / 679
# Processed batch 314 / 679
# Processed batch 315 / 679
# Processed batch 316 / 679
# Processed batch 317 / 679
# Processed batch 318 / 679
# Processed batch 319 / 679
# Processed batch 320 / 679
# Processed batch 321 / 679
# Processed batch 322 / 679
# Processed batch 323 / 679
# Processed batch 324 / 679
# Processed batch 325 / 679
# Processed batch 326 / 679
# Processed batch 327 / 679
# Processed batch 328 / 679
# Processed batch 329 / 679
# Processed batch 330 / 679
# Processed batch 331 / 679
# Processed batch 332 / 679
# Processed batch 333 / 679
# Processed batch 334 / 679
# Processed batch 335 / 679
# Processed batch 336 / 679
# Processed batch 337 / 679
# Processed batch 338 / 679
# Processed batch 339 / 679
# Processed batch 340 / 679
# Processed batch 341 / 679
# Processed batch 342 / 679
# Processed batch 343 / 679
# Processed batch 344 / 679
# Processed batch 345 / 679
# Processed batch 346 / 679
# Processed batch 347 / 679
# Processed batch 348 / 679
# Processed batch 349 / 679
# Processed batch 350 / 679
# Processed batch 351 / 679
# Processed batch 352 / 679
# Processed batch 353 / 679
# Processed batch 354 / 679
# Processed batch 355 / 679
# Processed batch 356 / 679
# Processed batch 357 / 679
# Processed batch 358 / 679
# Processed batch 359 / 679
# Processed batch 360 / 679
# Processed batch 361 / 679
# Processed batch 362 / 679
# Processed batch 363 / 679
# Processed batch 364 / 679
# Processed batch 365 / 679
# Processed batch 366 / 679
# Processed batch 367 / 679
# Processed batch 368 / 679
# Processed batch 369 / 679
# Processed batch 370 / 679
# Processed batch 371 / 679
# Processed batch 372 / 679
# Processed batch 373 / 679
# Processed batch 374 / 679
# Processed batch 375 / 679
# Processed batch 376 / 679
# Processed batch 377 / 679
# Processed batch 378 / 679
# Processed batch 379 / 679
# Processed batch 380 / 679
# Processed batch 381 / 679
# Processed batch 382 / 679
# Processed batch 383 / 679
# Processed batch 384 / 679
# Processed batch 385 / 679
# Processed batch 386 / 679
# Processed batch 387 / 679
# Processed batch 388 / 679
# Processed batch 389 / 679
# Processed batch 390 / 679
# Processed batch 391 / 679
# Processed batch 392 / 679
# Processed batch 393 / 679
# Processed batch 394 / 679
# Processed batch 395 / 679
# Processed batch 396 / 679
# Processed batch 397 / 679
# Processed batch 398 / 679
# Processed batch 399 / 679
# Processed batch 400 / 679
# Processed batch 401 / 679
# Processed batch 402 / 679
# Processed batch 403 / 679
# Processed batch 404 / 679
# Processed batch 405 / 679
# Processed batch 406 / 679
# Processed batch 407 / 679
# Processed batch 408 / 679
# Processed batch 409 / 679
# Processed batch 410 / 679
# Processed batch 411 / 679
# Processed batch 412 / 679
# Processed batch 413 / 679
# Processed batch 414 / 679
# Processed batch 415 / 679
# Processed batch 416 / 679
# Processed batch 417 / 679
# Processed batch 418 / 679
# Processed batch 419 / 679
# Processed batch 420 / 679
# Processed batch 421 / 679
# Processed batch 422 / 679
# Processed batch 423 / 679
# Processed batch 424 / 679
# Processed batch 425 / 679
# Processed batch 426 / 679
# Processed batch 427 / 679
# Processed batch 428 / 679
# Processed batch 429 / 679
# Processed batch 430 / 679
# Processed batch 431 / 679
# Processed batch 432 / 679
# Processed batch 433 / 679
# Processed batch 434 / 679
# Processed batch 435 / 679
# Processed batch 436 / 679
# Processed batch 437 / 679
# Processed batch 438 / 679
# Processed batch 439 / 679
# Processed batch 440 / 679
# Processed batch 441 / 679
# Processed batch 442 / 679
# Processed batch 443 / 679
# Processed batch 444 / 679
# Processed batch 445 / 679
# Processed batch 446 / 679
# Processed batch 447 / 679
# Processed batch 448 / 679
# Processed batch 449 / 679
# Processed batch 450 / 679
# Processed batch 451 / 679
# Processed batch 452 / 679
# Processed batch 453 / 679
# Processed batch 454 / 679
# Processed batch 455 / 679
# Processed batch 456 / 679
# Processed batch 457 / 679
# Processed batch 458 / 679
# Processed batch 459 / 679
# Processed batch 460 / 679
# Processed batch 461 / 679
# Processed batch 462 / 679
# Processed batch 463 / 679
# Processed batch 464 / 679
# Processed batch 465 / 679
# Processed batch 466 / 679
# Processed batch 467 / 679
# Processed batch 468 / 679
# Processed batch 469 / 679
# Processed batch 470 / 679
# Processed batch 471 / 679
# Processed batch 472 / 679
# Processed batch 473 / 679
# Processed batch 474 / 679
# Processed batch 475 / 679
# Processed batch 476 / 679
# Processed batch 477 / 679
# Processed batch 478 / 679
# Processed batch 479 / 679
# Processed batch 480 / 679
# Processed batch 481 / 679
# Processed batch 482 / 679
# Processed batch 483 / 679
# Processed batch 484 / 679
# Processed batch 485 / 679
# Processed batch 486 / 679
# Processed batch 487 / 679
# Processed batch 488 / 679
# Processed batch 489 / 679
# Processed batch 490 / 679
# Processed batch 491 / 679
# Processed batch 492 / 679
# Processed batch 493 / 679
# Processed batch 494 / 679
# Processed batch 495 / 679
# Processed batch 496 / 679
# Processed batch 497 / 679
# Processed batch 498 / 679
# Processed batch 499 / 679
# Processed batch 500 / 679
# Processed batch 501 / 679
# Processed batch 502 / 679
# Processed batch 503 / 679
# Processed batch 504 / 679
# Processed batch 505 / 679
# Processed batch 506 / 679
# Processed batch 507 / 679
# Processed batch 508 / 679
# Processed batch 509 / 679
# Processed batch 510 / 679
# Processed batch 511 / 679
# Processed batch 512 / 679
# Processed batch 513 / 679
# Processed batch 514 / 679
# Processed batch 515 / 679
# Processed batch 516 / 679
# Processed batch 517 / 679
# Processed batch 518 / 679
# Processed batch 519 / 679
# Processed batch 520 / 679
# Processed batch 521 / 679
# Processed batch 522 / 679
# Processed batch 523 / 679
# Processed batch 524 / 679
# Processed batch 525 / 679
# Processed batch 526 / 679
# Processed batch 527 / 679
# Processed batch 528 / 679
# Processed batch 529 / 679
# Processed batch 530 / 679
# Processed batch 531 / 679
# Processed batch 532 / 679
# Processed batch 533 / 679
# Processed batch 534 / 679
# Processed batch 535 / 679
# Processed batch 536 / 679
# Processed batch 537 / 679
# Processed batch 538 / 679
# Processed batch 539 / 679
# Processed batch 540 / 679
# Processed batch 541 / 679
# Processed batch 542 / 679
# Processed batch 543 / 679
# Processed batch 544 / 679
# Processed batch 545 / 679
# Processed batch 546 / 679
# Processed batch 547 / 679
# Processed batch 548 / 679
# Processed batch 549 / 679
# Processed batch 550 / 679
# Processed batch 551 / 679
# Processed batch 552 / 679
# Processed batch 553 / 679
# Processed batch 554 / 679
# Processed batch 555 / 679
# Processed batch 556 / 679
# Processed batch 557 / 679
# Processed batch 558 / 679
# Processed batch 559 / 679
# Processed batch 560 / 679
# Processed batch 561 / 679
# Processed batch 562 / 679
# Processed batch 563 / 679
# Processed batch 564 / 679
# Processed batch 565 / 679
# Processed batch 566 / 679
# Processed batch 567 / 679
# Processed batch 568 / 679
# Processed batch 569 / 679
# Processed batch 570 / 679
# Processed batch 571 / 679
# Processed batch 572 / 679
# Processed batch 573 / 679
# Processed batch 574 / 679
# Processed batch 575 / 679
# Processed batch 576 / 679
# Processed batch 577 / 679
# Processed batch 578 / 679
# Processed batch 579 / 679
# Processed batch 580 / 679
# Processed batch 581 / 679
# Processed batch 582 / 679
# Processed batch 583 / 679
# Processed batch 584 / 679
# Processed batch 585 / 679
# Processed batch 586 / 679
# Processed batch 587 / 679
# Processed batch 588 / 679
# Processed batch 589 / 679
# Processed batch 590 / 679
# Processed batch 591 / 679
# Processed batch 592 / 679
# Processed batch 593 / 679
# Processed batch 594 / 679
# Processed batch 595 / 679
# Processed batch 596 / 679
# Processed batch 597 / 679
# Processed batch 598 / 679
# Processed batch 599 / 679
# Processed batch 600 / 679
# Processed batch 601 / 679
# Processed batch 602 / 679
# Processed batch 603 / 679
# Processed batch 604 / 679
# Processed batch 605 / 679
# Processed batch 606 / 679
# Processed batch 607 / 679
# Processed batch 608 / 679
# Processed batch 609 / 679
# Processed batch 610 / 679
# Processed batch 611 / 679
# Processed batch 612 / 679
# Processed batch 613 / 679
# Processed batch 614 / 679
# Processed batch 615 / 679
# Processed batch 616 / 679
# Processed batch 617 / 679
# Processed batch 618 / 679
# Processed batch 619 / 679
# Processed batch 620 / 679
# Processed batch 621 / 679
# Processed batch 622 / 679
# Processed batch 623 / 679
# Processed batch 624 / 679
# Processed batch 625 / 679
# Processed batch 626 / 679
# Processed batch 627 / 679
# Processed batch 628 / 679
# Processed batch 629 / 679
# Processed batch 630 / 679
# Processed batch 631 / 679
# Processed batch 632 / 679
# Processed batch 633 / 679
# Processed batch 634 / 679
# Processed batch 635 / 679
# Processed batch 636 / 679
# Processed batch 637 / 679
# Processed batch 638 / 679
# Processed batch 639 / 679
# Processed batch 640 / 679
# Processed batch 641 / 679
# Processed batch 642 / 679
# Processed batch 643 / 679
# Processed batch 644 / 679
# Processed batch 645 / 679
# Processed batch 646 / 679
# Processed batch 647 / 679
# Processed batch 648 / 679
# Processed batch 649 / 679
# Processed batch 650 / 679
# Processed batch 651 / 679
# Processed batch 652 / 679
# Processed batch 653 / 679
# Processed batch 654 / 679
# Processed batch 655 / 679
# Processed batch 656 / 679
# Processed batch 657 / 679
# Processed batch 658 / 679
# Processed batch 659 / 679
# Processed batch 660 / 679
# Processed batch 661 / 679
# Processed batch 662 / 679
# Processed batch 663 / 679
# Processed batch 664 / 679
# Processed batch 665 / 679
# Processed batch 666 / 679
# Processed batch 667 / 679
# Processed batch 668 / 679
# Processed batch 669 / 679
# Processed batch 670 / 679
# Processed batch 671 / 679
# Processed batch 672 / 679
# Processed batch 673 / 679
# Processed batch 674 / 679
# Processed batch 675 / 679
# Processed batch 676 / 679
# Processed batch 677 / 679
# Processed batch 678 / 679
# Processed batch 679 / 679
# Final embedding shape: (43410, 768)

# %%
# Splitting

# Normalize inputs for quantum circuit
X_train = (X_train / np.linalg.norm(X_train, axis=1, keepdims=True)) * np.pi
X_test = (X_test / np.linalg.norm(X_test, axis=1, keepdims=True)) * np.pi
                                # 27 emotions + neutral

# %%
# One-Hot Encoding Labels

y_train_onehot = onp.eye(n_classes)[y_train]
y_test_onehot = onp.eye(n_classes)[y_test]

# %%
# The Setup of Quantum Device

n_qubits = 8                                              # Scaling 8 qubits for deeper feature mapping
dev = qml.device("default.qubit", wires=n_qubits)

# %%
# The Build of the Scaled Quantum circuit (Quite heavy circuit we're using, look at the numbber of Qubits)

@qml.qnode(dev)

def quantum_circuit(inputs, weights):
  qml.templates.AngleEmbedding(inputs[:n_qubits], wires=range(n_qubits), rotation='Y')
  qml.templates.StronglyEntanglingLayers(weights, wires=range(n_qubits))
  return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)]

# %%
# Defining Prediction Logic

from pennylane import math as qml_math

def softmax(x):
    e_x = qml_math.exp(x - qml_math.max(x, axis=1, keepdims=True))
    return e_x / qml_math.sum(e_x, axis=1, keepdims=True)


def predict(X, weights):
    preds = [quantum_circuit(x, weights) for x in X]
    logits = qml_math.stack(preds)
    logits = qml_math.matmul(logits, W_output) + b_output
    return logits  # Raw scores

# %%
# Initializing Parameters

n_layers = 3  # Pretty Deep

np.random.seed(42)

# Correct weight without requires_grad coz Pennylane does not have it, ealier was including it
weights = qml.numpy.array(np.random.uniform(low=-np.pi, high=np.pi, size=(n_layers, n_qubits, 3)), requires_grad=True)
W_output = qml.numpy.array(0.1 * np.random.randn(n_qubits, n_classes), requires_grad=True)
b_output = qml.numpy.array(0.1 * np.random.randn(n_classes), requires_grad=True)

# %%
# THE GREAT TRAINING LOOP (Scaled with progress monitoring system)

opt = qml.AdamOptimizer(stepsize=0.01)
epochs = 100
batch_size = 64
accuracy_history = []

for epoch in range(epochs):
  batch_index = onp.random.randint(0, len(X_train), batch_size)
  X_batch = X_train[batch_index]
  y_batch = y_train_onehot[batch_index]

  def cost(weights):
    preds = predict(X_batch, weights)
    return qml_math.mean(qml_math.sum((y_batch - preds) ** 2, axis=1))

  weights = opt.step(cost, weights)

  if epoch % 5 == 0:
    y_pred_logits = predict(X_test, weights)
    acc = accuracy_score(onp.array(y_test), onp.argmax(y_pred_logits, axis=1))
    accuracy_history.append(acc)
    print(f"Epoch {epoch}: Test Accuracy = {acc:.2f}")
# Out:
# Epoch 0: Test Accuracy = 0.03
# /usr/local/lib/python3.11/dist-packages/autograd/tracer.py:16: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# Epoch 5: Test Accuracy = 0.03
# /usr/local/lib/python3.11/dist-packages/autograd/tracer.py:16: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# Epoch 10: Test Accuracy = 0.03
# /usr/local/lib/python3.11/dist-packages/autograd/tracer.py:16: UserWarning: Output seems independent of input.
#   warnings.warn("Output seems independent of input.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-32-347820346.py in <cell line: 0>()
#      18
#      19   if epoch % 5 == 0:
# ---> 20     y_pred_logits = predict(X_test, weights)
#      21     acc = accuracy_score(onp.array(y_test), onp.argmax(y_pred_logits, axis=1))
#      22     accuracy_history.append(acc)
#
# /tmp/ipython-input-30-3084184298.py in predict(X, weights)
#       9
#      10 def predict(X, weights):
# ---> 11     preds = [quantum_circuit(x, weights) for x in X]
#      12     logits = qml_math.stack(preds)
#      13     logits = qml_math.matmul(logits, W_output) + b_output
#
# /tmp/ipython-input-30-3084184298.py in <listcomp>(.0)
#       9
#      10 def predict(X, weights):
# ---> 11     preds = [quantum_circuit(x, weights) for x in X]
#      12     logits = qml_math.stack(preds)
#      13     logits = qml_math.matmul(logits, W_output) + b_output
#
# /usr/local/lib/python3.11/dist-packages/pennylane/workflow/qnode.py in __call__(self, *args, **kwargs)
#     880
#     881             return capture_qnode(self, *args, **kwargs)
# --> 882         return self._impl_call(*args, **kwargs)
#     883
#     884
#
# /usr/local/lib/python3.11/dist-packages/pennylane/workflow/qnode.py in _impl_call(self, *args, **kwargs)
#     853         self._transform_program.set_classical_component(self, args, kwargs)
#     854
# --> 855         res = qml.execute(
#     856             (tape,),
#     857             device=self.device,
#
# /usr/local/lib/python3.11/dist-packages/pennylane/workflow/execution.py in execute(tapes, device, diff_method, interface, transform_program, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, mcm_config, config, inner_transform)
#     237
#     238     #### Executing the configured setup #####
# --> 239     tapes, post_processing = transform_program(tapes)
#     240
#     241     if transform_program.is_informative:
#
# /usr/local/lib/python3.11/dist-packages/pennylane/transforms/core/transform_program.py in __call__(self, *args, **kwargs)
#     641         if type(args[0]).__name__ == "Jaxpr":
#     642             return self.__call_jaxpr(*args, **kwargs)
# --> 643         return self.__call_tapes(*args, **kwargs)
#
# /usr/local/lib/python3.11/dist-packages/pennylane/transforms/core/transform_program.py in __call_tapes(self, tapes)
#     578                 if argnums is not None:
#     579                     tape.trainable_params = argnums[j]
# --> 580                 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     581                 execution_tapes.extend(new_tapes)
#     582
#
# /usr/local/lib/python3.11/dist-packages/pennylane/devices/preprocess.py in decompose(tape, stopping_condition, stopping_condition_shots, skip_initial_state_prep, decomposer, name, error)
#     399     try:
#     400
# --> 401         new_ops = [
#     402             final_op
#     403             for op in tape.operations[len(prep_op) :]
#
# /usr/local/lib/python3.11/dist-packages/pennylane/devices/preprocess.py in <listcomp>(.0)
#     399     try:
#     400
# --> 401         new_ops = [
#     402             final_op
#     403             for op in tape.operations[len(prep_op) :]
#
# /usr/local/lib/python3.11/dist-packages/pennylane/devices/preprocess.py in _operator_decomposition_gen(op, acceptance_function, decomposer, max_expansion, current_depth, name, error)
#      62     else:
#      63         try:
# ---> 64             decomp = decomposer(op)
#      65             current_depth += 1
#      66         except qml.operation.DecompositionUndefinedError as e:
#
# /usr/local/lib/python3.11/dist-packages/pennylane/devices/preprocess.py in decomposer(op)
#     385
#     386         def decomposer(op):
# --> 387             return op.decomposition()
#     388
#     389     if stopping_condition_shots is not None and tape.shots:
#
# /usr/local/lib/python3.11/dist-packages/pennylane/operation.py in decomposition(self)
#    1335             list[Operator]: decomposition of the operator
#    1336         """
# -> 1337         return self.compute_decomposition(
#    1338             *self.parameters, wires=self.wires, **self.hyperparameters
#    1339         )
#
# /usr/local/lib/python3.11/dist-packages/pennylane/templates/layers/strongly_entangling.py in compute_decomposition(weights, wires, ranges, imprimitive)
#     219                 for i in range(len(wires)):
#     220                     act_on = wires.subset([i, i + ranges[l]], periodic_boundary=True)
# --> 221                     op_list.append(imprimitive(wires=act_on))
#     222
#     223         return op_list
#
# /usr/local/lib/python3.11/dist-packages/pennylane/capture/capture_meta.py in new_f(*args, **kwargs)
#      28
#      29     def new_f(*args, **kwargs):
# ---> 30         return f(*args, **kwargs)
#      31
#      32     return new_f
#
# /usr/local/lib/python3.11/dist-packages/pennylane/capture/capture_meta.py in __call__(cls, *args, **kwargs)
#      98             # use bind to construct the class if we want class construction to add it to the jaxpr
#      99             return cls._primitive_bind_call(*args, **kwargs)
# --> 100         return type.__call__(cls, *args, **kwargs)
#     101
#     102
#
# /usr/local/lib/python3.11/dist-packages/pennylane/ops/op_math/controlled_ops.py in __init__(self, wires, id)
#    1041         # We use type.__call__ instead of calling the class directly so that we don't bind the
#    1042         # operator primitive when new program capture is enabled
# -> 1043         base = type.__call__(qml.X, wires=wires[1:])
#    1044         super().__init__(base, wires[:1], id=id)
#    1045
#
# /usr/local/lib/python3.11/dist-packages/pennylane/ops/qubit/non_parametric_ops.py in __init__(self, wires, id)
#     290
#     291     def __init__(self, wires: WiresLike, id: Optional[str] = None):
# --> 292         super().__init__(wires=wires, id=id)
#     293
#     294     def label(
#
# /usr/local/lib/python3.11/dist-packages/pennylane/operation.py in __init__(self, wires, id, *params)
#    1921         id: Optional[str] = None,
#    1922     ):
# -> 1923         super().__init__(*params, wires=wires, id=id)
#    1924
#    1925         # check the grad_recipe validity
#
# /usr/local/lib/python3.11/dist-packages/pennylane/operation.py in __init__(self, wires, id, *params)
#    1155                 )
#    1156
# -> 1157         elif len(self._wires) != self.num_wires:
#    1158             raise ValueError(
#    1159                 f"{self.name}: wrong number of wires. "
#
# /usr/local/lib/python3.11/dist-packages/pennylane/wires.py in __len__(self)
#     149         return self._labels.__iter__()
#     150
# --> 151     def __len__(self):
#     152         """Method to support ``len()``."""
#     153         return len(self._labels)
#
# KeyboardInterrupt:

# %%
gradients = qml.grad(cost)(weights)
print("Gradient norms by layer:", [qml_math.linalg.norm(g) for g in gradients])
print("Overall gradient norm:", sum(qml_math.linalg.norm(g) for g in gradients))
# Out:
# Gradient norms by layer: [0.0, 0.0, 0.0]
# Overall gradient norm: 0.0

# %%
# Final Evaluation

y_pred_final = predict(X_test, weights)
final_acc = accuracy_score(onp.array(y_test), onp.argmax(y_pred_final, axis=1))
print(f"Final Test Accuracy: {final_acc:.2f}")


print("Detailed Classification Report:")
print(classification_report(onp.array(y_test), onp.argmax(y_pred_final, axis=1)))
# Out:
# Final Test Accuracy: 0.02
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       839
#            1       0.00      0.00      0.00       461
#            2       0.00      0.00      0.00       319
#            3       0.00      0.00      0.00       406
#            4       0.00      0.00      0.00       492
#            5       0.00      0.00      0.00       164
#            6       0.00      0.00      0.00       258
#            7       0.00      0.00      0.00       370
#            8       0.00      0.00      0.00       100
#            9       0.00      0.00      0.00       216
#           10       0.00      0.00      0.00       331
#           11       0.00      0.00      0.00       115
#           12       0.00      0.00      0.00        45
#           13       0.00      0.00      0.00       149
#           14       0.00      0.00      0.00        98
#           15       0.00      0.00      0.00       427
#           16       0.00      0.00      0.00        13
#           17       0.02      1.00      0.05       211
#           18       0.00      0.00      0.00       298
#           19       0.00      0.00      0.00        20
#           20       0.00      0.00      0.00       191
#           21       0.00      0.00      0.00        12
#           22       0.00      0.00      0.00       141
#           23       0.00      0.00      0.00        24
#           24       0.00      0.00      0.00        95
#           25       0.00      0.00      0.00       169
#           26       0.00      0.00      0.00       148
#           27       0.00      0.00      0.00      2570
#
#     accuracy                           0.02      8682
#    macro avg       0.00      0.04      0.00      8682
# weighted avg       0.00      0.02      0.00      8682
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#Accuracy Plot

plt.figure(figsize=(10,6))
plt.plot(range(0, epochs, 5), accuracy_history, marker='o', color='blue')
plt.xlabel("Epochs")
plt.ylabel("Test Accuracy")
plt.title("Quantum-Classical Hybrid Model Accuracy Over Epochs")
plt.grid(True)
plt.show()
